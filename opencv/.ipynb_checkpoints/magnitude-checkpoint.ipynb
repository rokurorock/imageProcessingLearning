# %% [markdown]
# # 	cv.magnitude(	x, y[, magnitude]	)
# ### 概要
# マグニチュードって数学的な"大きさ"って意味らしい
#
# ２次元ベクトルの大きさを求める関数
# ### 要点
#
# ・magunitude=√𝚡 exp{2}+𝚢 exp{2} を求める
#
# ・要は2次元ベクトルの大きさを列ごとに求める関数
#
#
#
#
#
# ### 引数(公式リファレンスから引用)
# **x**	numpy配列 floatの値の配列でなければならない
# **y**	numpy配列 floatの値の配列でなければならない。また、xと同じサイズでなければならない
#
#
#
#
# ### 戻り値
# **magnitude**    周波数領域の情報
#
#
# ### 参考URL
# [公式ドキュメント](https://docs.opencv.org/master/d2/de8/group__core__array.html#gadd6cf9baf2b8b704a11b5f04aaf4f39d)

# %%
import cv2
import matplotlib.pyplot as plt
from ipywidgets import interact
import numpy as np

# %%
def main():
    array1 = np.array([1.0, 2.0, 3.0])
    array2 = np.array([1.0, 1.0, 1.0])
    
    print(cv2.magnitude(array1,array2))
    
    
   
    
main()
# Out:
# [[1.41421356]
#  [2.23606798]
#  [3.16227766]]
